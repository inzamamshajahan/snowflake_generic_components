# %%
import code_library as cl
from dotenv import dotenv_values

# %%
secrets = dotenv_values(".env")

# %%
connection_parameters = {
"account":secrets['account'], 
"user":secrets['user'], 
"password": secrets['password'], 
"role":secrets['role'], 
"warehouse":"COMPUTE_WH", 
"database":"DEMO_DB", 
"schema":"PUBLIC" 
}

# %%
session = cl.snowconnection(connection_parameters)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 session = cl.snowconnection(connection_parameters)
#
# File ~/environment/snowflake_generic_components/code_library.py:5, in snowconnection(connection_config)
#       4 def snowconnection(connection_config):
# ----> 5     session = Session.builder.configs(connection_config).create()
#       6     session_details = session.create_dataframe(
#       7         [
#       8             [session._session_id,
#    (...)
#      13         ],
#      14             schema=["session_id","user_name","warehouse","role"])
#      16     session_details.write.mode("append").save_as_table("session_audit")
#
# File ~/environment/venv/lib/python3.9/site-packages/snowflake/snowpark/session.py:293, in Session.SessionBuilder.create(self)
#     291 def create(self) -> "Session":
#     292     """Creates a new Session."""
# --> 293     session = self._create_internal(self._options.get("connection"))
#     294     return session
#
# File ~/environment/venv/lib/python3.9/site-packages/snowflake/snowpark/session.py:313, in Session.SessionBuilder._create_internal(self, conn)
#     310 if "paramstyle" not in self._options:
#     311     self._options["paramstyle"] = "qmark"
#     312 new_session = Session(
# --> 313     ServerConnection({}, conn) if conn else ServerConnection(self._options),
#     314     self._options,
#     315 )
#     317 if "password" in self._options:
#     318     self._options["password"] = None
#
# File ~/environment/venv/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:136, in ServerConnection.__init__(self, options, conn)
#     134 self._lower_case_parameters = {k.lower(): v for k, v in options.items()}
#     135 self._add_application_name()
# --> 136 self._conn = conn if conn else connect(**self._lower_case_parameters)
#     137 if "password" in self._lower_case_parameters:
#     138     self._lower_case_parameters["password"] = None
#
# File ~/environment/venv/lib64/python3.9/site-packages/snowflake/connector/__init__.py:55, in Connect(**kwargs)
#      53 @wraps(SnowflakeConnection.__init__)
#      54 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 55     return SnowflakeConnection(**kwargs)
#
# File ~/environment/venv/lib64/python3.9/site-packages/snowflake/connector/connection.py:442, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
#     440     kwargs = _get_default_connection_params()
#     441 self.__set_error_attributes()
# --> 442 self.connect(**kwargs)
#     443 self._telemetry = TelemetryClient(self._rest)
#     444 self.expired = False
#
# File ~/environment/venv/lib64/python3.9/site-packages/snowflake/connector/connection.py:745, in SnowflakeConnection.connect(self, **kwargs)
#     743             raise Exception(str(exceptions_dict))
#     744 else:
# --> 745     self.__open_connection()
#
# File ~/environment/venv/lib64/python3.9/site-packages/snowflake/connector/connection.py:1073, in SnowflakeConnection.__open_connection(self)
#    1065 else:
#    1066     # okta URL, e.g., https://<account>.okta.com/
#    1067     self.auth_class = AuthByOkta(
#    1068         application=self.application,
#    1069         timeout=self._login_timeout,
#    1070         backoff_generator=self._backoff_generator,
#    1071     )
# -> 1073 self.authenticate_with_retry(self.auth_class)
#    1075 self._password = None  # ensure password won't persist
#    1076 self.auth_class.reset_secrets()
#
# File ~/environment/venv/lib64/python3.9/site-packages/snowflake/connector/connection.py:1345, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1342 def authenticate_with_retry(self, auth_instance) -> None:
#    1343     # make some changes if needed before real __authenticate
#    1344     try:
# -> 1345         self._authenticate(auth_instance)
#    1346     except ReauthenticationRequest as ex:
#    1347         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1348         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File ~/environment/venv/lib64/python3.9/site-packages/snowflake/connector/connection.py:1373, in SnowflakeConnection._authenticate(self, auth_instance)
#    1371 auth_instance._retry_ctx.set_start_time()
#    1372 try:
# -> 1373     auth.authenticate(
#    1374         auth_instance=auth_instance,
#    1375         account=self.account,
#    1376         user=self.user,
#    1377         database=self.database,
#    1378         schema=self.schema,
#    1379         warehouse=self.warehouse,
#    1380         role=self.role,
#    1381         passcode=self._passcode,
#    1382         passcode_in_password=self._passcode_in_password,
#    1383         mfa_callback=self._mfa_callback,
#    1384         password_callback=self._password_callback,
#    1385         session_parameters=self._session_parameters,
#    1386     )
#    1387 except OperationalError as e:
#    1388     logger.debug(
#    1389         "Operational Error raised at authentication"
#    1390         f"for authenticator: {type(auth_instance).__name__}"
#    1391     )
#
# File ~/environment/venv/lib64/python3.9/site-packages/snowflake/connector/auth/_auth.py:401, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     399     if isinstance(auth_instance, AuthByUsrPwdMfa):
#     400         delete_temporary_credential(self._rest._host, user, MFA_TOKEN)
# --> 401     Error.errorhandler_wrapper(
#     402         self._rest._connection,
#     403         None,
#     404         DatabaseError,
#     405         {
#     406             "msg": (
#     407                 "Failed to connect to DB: {host}:{port}. " "{message}"
#     408             ).format(
#     409                 host=self._rest._host,
#     410                 port=self._rest._port,
#     411                 message=ret["message"],
#     412             ),
#     413             "errno": ER_FAILED_TO_CONNECT_TO_DB,
#     414             "sqlstate": SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#     415         },
#     416     )
#     417 else:
#     418     logger.debug(
#     419         "token = %s",
#     420         "******"
#     421         if ret["data"] and ret["data"].get("token") is not None
#     422         else "NULL",
#     423     )
#
# File ~/environment/venv/lib64/python3.9/site-packages/snowflake/connector/errors.py:290, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     267 @staticmethod
#     268 def errorhandler_wrapper(
#     269     connection: SnowflakeConnection | None,
#    (...)
#     272     error_value: dict[str, Any],
#     273 ) -> None:
#     274     """Error handler wrapper that calls the errorhandler method.
#     275
#     276     Args:
#    (...)
#     287         exception to the first handler in that order.
#     288     """
# --> 290     handed_over = Error.hand_to_other_handler(
#     291         connection,
#     292         cursor,
#     293         error_class,
#     294         error_value,
#     295     )
#     296     if not handed_over:
#     297         raise Error.errorhandler_make_exception(
#     298             error_class,
#     299             error_value,
#     300         )
#
# File ~/environment/venv/lib64/python3.9/site-packages/snowflake/connector/errors.py:348, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     346     return True
#     347 elif connection is not None:
# --> 348     connection.errorhandler(connection, cursor, error_class, error_value)
#     349     return True
#     350 return False
#
# File ~/environment/venv/lib64/python3.9/site-packages/snowflake/connector/errors.py:221, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     219 errno = error_value.get("errno")
#     220 done_format_msg = error_value.get("done_format_msg")
# --> 221 raise error_class(
#     222     msg=error_value.get("msg"),
#     223     errno=None if errno is None else int(errno),
#     224     sqlstate=error_value.get("sqlstate"),
#     225     sfqid=error_value.get("sfqid"),
#     226     query=error_value.get("query"),
#     227     done_format_msg=(
#     228         None if done_format_msg is None else bool(done_format_msg)
#     229     ),
#     230     connection=connection,
#     231     cursor=cursor,
#     232 )
#
# DatabaseError: 250001 (08001): Failed to connect to DB: znfbyid-dv25735.snowflakecomputing.com:443. Your user account has been temporarily locked due to too many failed attempts. Try again after 15 minutes or contact your account administrator for assistance. For more information about this error, go to https://community.snowflake.com/s/error-your-user-login-has-been-locked.
